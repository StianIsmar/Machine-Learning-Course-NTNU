# %%
import numpy as np

data = np.loadtxt('train_1d_reg_data.csv', delimiter=',', skiprows=1, unpack=False)
x = data[...,0]
y = data[...,1]
print(data)
print(x)
print(" ")
print(y)
# Out:
# [[0.418 0.438]
#  [0.722 0.606]
#  [0.    0.102]
#  [0.303 0.323]
#  [0.147 0.13 ]
#  [0.092 0.468]
#  [0.187 0.263]
#  [0.346 0.465]
#  [0.398 0.321]
#  [0.54  0.613]
#  [0.42  0.236]
#  [0.687 0.712]
#  [0.205 0.324]
#  [0.88  0.961]
#  [0.027 0.075]
#  [0.672 0.606]
#  [0.418 0.494]
#  [0.56  0.675]
#  [0.141 0.242]
#  [0.199 0.335]
#  [0.803 0.425]
#  [0.971 0.673]
#  [0.314 0.443]
#  [0.694 0.738]
#  [0.879 0.684]
#  [0.897 0.964]
#  [0.085 0.463]
#  [0.039 0.226]
#  [0.17  0.03 ]
#  [0.88  0.512]
#  [0.099 0.177]
#  [0.422 0.582]
#  [0.96  0.799]
#  [0.535 0.276]
#  [0.694 0.583]
#  [0.316 0.579]
#  [0.688 0.563]
#  [0.837 0.606]
#  [0.018 0.458]
#  [0.752 0.65 ]
#  [0.992 0.726]
#  [0.75  0.683]
#  [0.281 0.374]
#  [0.791 0.616]
#  [0.103 0.409]
#  [0.449 0.598]
#  [0.911 0.832]
#  [0.294 0.368]
#  [0.288 0.509]
#  [0.13  0.28 ]
#  [0.019 0.275]
#  [0.681 0.722]
#  [0.212 0.426]
#  [0.266 0.57 ]
#  [0.493 0.546]
#  [0.053 0.047]
#  [0.576 0.408]
#  [0.147 0.451]
# ...

# %%
X = np.ones((len(x), 2))
for obs in x:
    print(obs)

# %%
# Out:
# 0.418
# 0.722
# 0.0
# 0.303
# 0.147
# 0.092
# 0.187
# 0.346
# 0.398
# 0.54
# 0.42
# 0.687
# 0.205
# 0.88
# 0.027
# 0.672
# 0.418
# 0.56
# 0.141
# 0.199
# 0.803
# 0.971
# 0.314
# 0.694
# 0.879
# 0.897
# 0.085
# 0.039
# 0.17
# 0.88
# 0.099
# 0.422
# 0.96
# 0.535
# 0.694
# 0.316
# 0.688
# 0.837
# 0.018
# 0.752
# 0.992
# 0.75
# 0.281
# 0.791
# 0.103
# 0.449
# 0.911
# 0.294
# 0.288
# 0.13
# 0.019
# 0.681
# 0.212
# 0.266
# 0.493
# 0.053
# 0.576
# 0.147
# 0.591
# 0.702
# 0.103
# 0.415
# 0.696
# 0.415
# 0.05
# 0.537
# 0.666
# 0.516
# 0.947
# 0.588
# 0.906
# 0.138
# 0.14
# 0.81
# 0.399
# 0.166
# 0.93
# 0.349
# 0.753
# 0.728
# 0.886
# 0.625
# 0.753
# 0.35
# 0.271
# 0.898
# 0.429
# 0.967
# 0.665
# 0.623
# 0.115
# 0.952
# 0.451
# 0.58
# 0.409
# 0.238
# 0.906
# 0.575
# 0.003
# 0.619
# 0.327
# 0.528
# 0.888
# 0.358
# 0.911
# 0.625
# 0.016
# 0.932
# 0.693
# 1.0
# 0.173
# 0.137
# 0.935
# 0.699
# 0.066
# 0.757
# 0.756
# 0.925
# 0.713
# 0.125
# 0.02
# 0.026
# 0.028
# 0.247
# 0.862
# 0.54
# 0.554
# ...
