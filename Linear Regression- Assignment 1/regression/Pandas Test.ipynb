# %%
import pandas as pd

data = pd.read_csv('train_1d_reg_data.csv')
print(data)
# Out:
#         x1      y
# 0    0.418  0.438
# 1    0.722  0.606
# 2    0.000  0.102
# 3    0.303  0.323
# 4    0.147  0.130
# 5    0.092  0.468
# 6    0.187  0.263
# 7    0.346  0.465
# 8    0.398  0.321
# 9    0.540  0.613
# 10   0.420  0.236
# 11   0.687  0.712
# 12   0.205  0.324
# 13   0.880  0.961
# 14   0.027  0.075
# 15   0.672  0.606
# 16   0.418  0.494
# 17   0.560  0.675
# 18   0.141  0.242
# 19   0.199  0.335
# 20   0.803  0.425
# 21   0.971  0.673
# 22   0.314  0.443
# 23   0.694  0.738
# 24   0.879  0.684
# 25   0.897  0.964
# 26   0.085  0.463
# 27   0.039  0.226
# 28   0.170  0.030
# 29   0.880  0.512
# ..     ...    ...
# 295  0.068  0.135
# 296  0.379  0.290
# 297  0.080  0.546
# 298  0.985  0.999
# 299  0.182  0.154
# 300  0.814  0.731
# 301  0.877  0.788
# 302  0.690  0.695
# 303  0.571  0.555
# 304  0.161  0.196
# 305  0.468  0.459
# 306  0.346  0.353
# 307  0.226  0.356
# 308  0.594  0.521
# 309  0.313  0.375
# 310  0.919  0.857
# 311  0.912  0.878
# 312  0.258  0.222
# ...
